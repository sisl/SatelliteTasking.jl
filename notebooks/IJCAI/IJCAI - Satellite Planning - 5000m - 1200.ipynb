# %%
# Package Setup
import Pkg;
# Pkg.update()

# Julia Packages
using Distributions
using LinearAlgebra
using Statistics
using PGFPlots

# Satellite Dynamics Packages
using SatelliteDynamics

# Load SatelliteTasking - Reclone to keep version current
Pkg.clone("..") # For some reason this doens't work with Pkg.add + PackageSpec. Why?
using SatelliteTasking
using SatelliteTasking.SatellitePlanning
using SatelliteTasking.Analysis

# Temporary for now
Pkg.add("JuMP")
Pkg.add("Gurobi")
using JuMP
using Gurobi
# Out:
# ┌ Info: Recompiling stale cache file /Users/deddy/.julia/compiled/v1.1/SatelliteDynamics/9LFbr.ji for SatelliteDynamics [0e7c1a32-1b9f-5532-88a4-e668712d6a4c]
# └ @ Base loading.jl:1184
# ┌ Warning: Pkg.clone is only kept for legacy CI script reasons, please use `add`
# └ @ Pkg.API /Users/osx/buildbot/slave/package_osx64/build/usr/share/julia/stdlib/v1.1/Pkg/src/API.jl:386
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]
# ┌ Info: Recompiling stale cache file /Users/deddy/.julia/compiled/v1.1/SatelliteTasking/HFrko.ji for SatelliteTasking [30f2e302-0ae1-11e9-1cda-0f4324764595]
# └ @ Base loading.jl:1184
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
# Configure simulation
epc0 = Epoch(2019, 1, 1, 0, 0, 0, tsys=:UTC) # Start of time span
epcf = Epoch(2019, 1, 2, 0, 0, 0, tsys=:UTC) # End of simulation time span

# Set Simulation Time Step
timestep = 1
dtmax    = 5

# Define Satellite Orbit
oe   = [R_EARTH + 500e3, 0, 90.0, 0, 0, 0]
eci0 = sOSCtoCART(oe, use_degrees=true)

# Numer of perturbed orbits to simulate
num_orbits = 110

# Set Perturbation Values 
pos_error = 5000 # Position knowledge error [m]
vel_error = 5    # Velocity knowledge error [m/s]
orb_mean  = zeros(Float64, 6)
orb_sdev  = vcat((pos_error/sqrt(3)*ones(Float64, 3))..., (vel_error/sqrt(3)*ones(Float64, 3))...)

# Simulate true and perturbed orbits
@time true_orbit, perturbed_orbits, eci_errors = simulate_orbits(num_orbits, epc0, epcf, eci0, orb_mean, orb_sdev, timestep=timestep, dtmax=dtmax);
# Out:
# Simulating perturbed orbit 1
# Simulating perturbed orbit 2
# Simulating perturbed orbit 3
# Simulating perturbed orbit 4
# Simulating perturbed orbit 5
# Simulating perturbed orbit 6
# Simulating perturbed orbit 7
# Simulating perturbed orbit 8
# Simulating perturbed orbit 9
# Simulating perturbed orbit 10
# Simulating perturbed orbit 11
# Simulating perturbed orbit 12
# Simulating perturbed orbit 13
# Simulating perturbed orbit 14
# Simulating perturbed orbit 15
# Simulating perturbed orbit 16
# Simulating perturbed orbit 17
# Simulating perturbed orbit 18
# Simulating perturbed orbit 19
# Simulating perturbed orbit 20
# Simulating perturbed orbit 21
# Simulating perturbed orbit 22
# Simulating perturbed orbit 23
# Simulating perturbed orbit 24
# Simulating perturbed orbit 25
# Simulating perturbed orbit 26
# Simulating perturbed orbit 27
# Simulating perturbed orbit 28
# Simulating perturbed orbit 29
# Simulating perturbed orbit 30
# Simulating perturbed orbit 31
# Simulating perturbed orbit 32
# Simulating perturbed orbit 33
# Simulating perturbed orbit 34
# Simulating perturbed orbit 35
# Simulating perturbed orbit 36
# Simulating perturbed orbit 37
# Simulating perturbed orbit 38
# Simulating perturbed orbit 39
# Simulating perturbed orbit 40
# Simulating perturbed orbit 41
# Simulating perturbed orbit 42
# Simulating perturbed orbit 43
# Simulating perturbed orbit 44
# Simulating perturbed orbit 45
# Simulating perturbed orbit 46
# Simulating perturbed orbit 47
# Simulating perturbed orbit 48
# Simulating perturbed orbit 49
# Simulating perturbed orbit 50
# Simulating perturbed orbit 51
# Simulating perturbed orbit 52
# Simulating perturbed orbit 53
# Simulating perturbed orbit 54
# Simulating perturbed orbit 55
# Simulating perturbed orbit 56
# Simulating perturbed orbit 57
# Simulating perturbed orbit 58
# Simulating perturbed orbit 59
# Simulating perturbed orbit 60
# Simulating perturbed orbit 61
# Simulating perturbed orbit 62
# Simulating perturbed orbit 63
# Simulating perturbed orbit 64
# Simulating perturbed orbit 65
# Simulating perturbed orbit 66
# Simulating perturbed orbit 67
# Simulating perturbed orbit 68
# Simulating perturbed orbit 69
# Simulating perturbed orbit 70
# Simulating perturbed orbit 71
# Simulating perturbed orbit 72
# Simulating perturbed orbit 73
# Simulating perturbed orbit 74
# Simulating perturbed orbit 75
# Simulating perturbed orbit 76
# Simulating perturbed orbit 77
# Simulating perturbed orbit 78
# Simulating perturbed orbit 79
# Simulating perturbed orbit 80
# Simulating perturbed orbit 81
# Simulating perturbed orbit 82
# Simulating perturbed orbit 83
# Simulating perturbed orbit 84
# Simulating perturbed orbit 85
# Simulating perturbed orbit 86
# Simulating perturbed orbit 87
# Simulating perturbed orbit 88
# Simulating perturbed orbit 89
# Simulating perturbed orbit 90
# Simulating perturbed orbit 91
# Simulating perturbed orbit 92
# Simulating perturbed orbit 93
# Simulating perturbed orbit 94
# Simulating perturbed orbit 95
# Simulating perturbed orbit 96
# Simulating perturbed orbit 97
# Simulating perturbed orbit 98
# Simulating perturbed orbit 99
# Simulating perturbed orbit 100
# Simulating perturbed orbit 101
# Simulating perturbed orbit 102
# Simulating perturbed orbit 103
# Simulating perturbed orbit 104
# Simulating perturbed orbit 105
# Simulating perturbed orbit 106
# Simulating perturbed orbit 107
# Simulating perturbed orbit 108
# Simulating perturbed orbit 109
# Simulating perturbed orbit 110
# 1358.731658 seconds (9.79 G allocations: 413.828 GiB, 14.93% gc time)

# %%
# Compute True and perturbed collects

# Load test images
# @time images = load_images("../data/landsat_test_150.json", collect_duration=5.0);
# @time images = load_images("../data/landsat_test_300.json", collect_duration=5.0);
# @time images = load_images("../data/landsat_test_600.json", collect_duration=5.0);
@time images = load_images("../data/landsat_test_1200.json", collect_duration=5.0);

num_images = length(images)

# Compute true and perturbed opportunities
@time true_opportunities, perturbed_opportunities, mean_diff, sdev_diff, missing_opportunities = compute_perturbed_opportunities(true_orbit, perturbed_orbits, images, epc_step=3600);

# 
@time collects = split_opportunities(true_opportunities, 10);

# Compute feasible collects
image_collects = group_image_collects(collects) # Group collects by image
num_feasible   = 0
for img in keys(image_collects)
    if length(image_collects[img]) > 0
        num_feasible += 1
    end
end
pct_feasible = num_feasible/num_images*100

println("$num_feasible out of $num_images images have collection opportunities.")
# Out:
#   0.445524 seconds (722.45 k allocations: 38.193 MiB, 4.76% gc time)
# Computing opportunities for perturbed orbit: 1
# Computing opportunities for perturbed orbit: 2
# Computing opportunities for perturbed orbit: 3
# Computing opportunities for perturbed orbit: 4
# Computing opportunities for perturbed orbit: 5
# Computing opportunities for perturbed orbit: 6
# Computing opportunities for perturbed orbit: 7
# Computing opportunities for perturbed orbit: 8
# Computing opportunities for perturbed orbit: 9
# Computing opportunities for perturbed orbit: 10
# Computing opportunities for perturbed orbit: 11
# Computing opportunities for perturbed orbit: 12
# Computing opportunities for perturbed orbit: 13
# Computing opportunities for perturbed orbit: 14
# Computing opportunities for perturbed orbit: 15
# Computing opportunities for perturbed orbit: 16
# Computing opportunities for perturbed orbit: 17
# Computing opportunities for perturbed orbit: 18
# Computing opportunities for perturbed orbit: 19
# Computing opportunities for perturbed orbit: 20
# Computing opportunities for perturbed orbit: 21
# Computing opportunities for perturbed orbit: 22
# Computing opportunities for perturbed orbit: 23
# Computing opportunities for perturbed orbit: 24
# Computing opportunities for perturbed orbit: 25
# Computing opportunities for perturbed orbit: 26
# Computing opportunities for perturbed orbit: 27
# Computing opportunities for perturbed orbit: 28
# Computing opportunities for perturbed orbit: 29
# Computing opportunities for perturbed orbit: 30
# Computing opportunities for perturbed orbit: 31
# Computing opportunities for perturbed orbit: 32
# Computing opportunities for perturbed orbit: 33
# Computing opportunities for perturbed orbit: 34
# Computing opportunities for perturbed orbit: 35
# Computing opportunities for perturbed orbit: 36
# Computing opportunities for perturbed orbit: 37
# Computing opportunities for perturbed orbit: 38
# Computing opportunities for perturbed orbit: 39
# Computing opportunities for perturbed orbit: 40
# Computing opportunities for perturbed orbit: 41
# Computing opportunities for perturbed orbit: 42
# Computing opportunities for perturbed orbit: 43
# Computing opportunities for perturbed orbit: 44
# Computing opportunities for perturbed orbit: 45
# Computing opportunities for perturbed orbit: 46
# Computing opportunities for perturbed orbit: 47
# Computing opportunities for perturbed orbit: 48
# Computing opportunities for perturbed orbit: 49
# Computing opportunities for perturbed orbit: 50
# Computing opportunities for perturbed orbit: 51
# Computing opportunities for perturbed orbit: 52
# Computing opportunities for perturbed orbit: 53
# Computing opportunities for perturbed orbit: 54
# Computing opportunities for perturbed orbit: 55
# Computing opportunities for perturbed orbit: 56
# Computing opportunities for perturbed orbit: 57
# Computing opportunities for perturbed orbit: 58
# Computing opportunities for perturbed orbit: 59
# Computing opportunities for perturbed orbit: 60
# Computing opportunities for perturbed orbit: 61
# Computing opportunities for perturbed orbit: 62
# Computing opportunities for perturbed orbit: 63
# Computing opportunities for perturbed orbit: 64
# Computing opportunities for perturbed orbit: 65
# Computing opportunities for perturbed orbit: 66
# Computing opportunities for perturbed orbit: 67
# Computing opportunities for perturbed orbit: 68
# Computing opportunities for perturbed orbit: 69
# Computing opportunities for perturbed orbit: 70
# Computing opportunities for perturbed orbit: 71
# Computing opportunities for perturbed orbit: 72
# Computing opportunities for perturbed orbit: 73
# Computing opportunities for perturbed orbit: 74
# Computing opportunities for perturbed orbit: 75
# Computing opportunities for perturbed orbit: 76
# Computing opportunities for perturbed orbit: 77
# Computing opportunities for perturbed orbit: 78
# Computing opportunities for perturbed orbit: 79
# Computing opportunities for perturbed orbit: 80
# Computing opportunities for perturbed orbit: 81
# Computing opportunities for perturbed orbit: 82
# Computing opportunities for perturbed orbit: 83
# Computing opportunities for perturbed orbit: 84
# Computing opportunities for perturbed orbit: 85
# Computing opportunities for perturbed orbit: 86
# Computing opportunities for perturbed orbit: 87
# Computing opportunities for perturbed orbit: 88
# Computing opportunities for perturbed orbit: 89
# Computing opportunities for perturbed orbit: 90
# Computing opportunities for perturbed orbit: 91
# Computing opportunities for perturbed orbit: 92
# Computing opportunities for perturbed orbit: 93
# Computing opportunities for perturbed orbit: 94
# Computing opportunities for perturbed orbit: 95
# Computing opportunities for perturbed orbit: 96
# Computing opportunities for perturbed orbit: 97
# Computing opportunities for perturbed orbit: 98
# Computing opportunities for perturbed orbit: 99
# Computing opportunities for perturbed orbit: 100
# Computing opportunities for perturbed orbit: 101
# Computing opportunities for perturbed orbit: 102
# Computing opportunities for perturbed orbit: 103
# Computing opportunities for perturbed orbit: 104
# Computing opportunities for perturbed orbit: 105
# Computing opportunities for perturbed orbit: 106
# Computing opportunities for perturbed orbit: 107
# Computing opportunities for perturbed orbit: 108
# Computing opportunities for perturbed orbit: 109
# Computing opportunities for perturbed orbit: 110
# 13603.756345 seconds (149.63 G allocations: 15.420 TiB, 20.61% gc time)
#   0.252041 seconds (648.50 k allocations: 31.519 MiB, 2.34% gc time)
# 1062 out of 1200 images have collection opportunities.

# %%
println(sdev_diff[1, :])
println(sdev_diff[2, :])
println(sdev_diff[3, :])
println(missing_opportunities)
# Out:
# [13.5461, 21.4995, 31.5753, 29.4135, 36.4065, 43.616, 48.076, 52.7187, 56.0265, 61.2919, 68.4095, 71.7073, 80.2003, 87.8933, 91.3777, 98.4415, 102.484, 111.335, 116.121, 125.495, 123.688, 136.725, 136.47, 145.236]
# [14.9862, 23.488, 33.9878, 32.5137, 39.4022, 47.1913, 49.6531, 57.1352, 60.4204, 66.0187, 73.7644, 77.8154, 83.9486, 91.6246, 92.7367, 102.658, 106.781, 118.362, 121.166, 129.789, 128.744, 139.841, 141.803, 148.496]
# [10.1799, 7.22966, 10.4006, 15.583, 10.0576, 9.21796, 18.5725, 17.3561, 17.9866, 11.8153, 12.0366, 21.8544, 15.9378, 15.9396, 18.9892, 18.2741, 12.9092, 26.5047, 11.0621, 23.6004, 17.3919, 21.4451, 22.906, 23.4955]
# [95, 354, 251, 16, 134, 85, 8, 441, 136, 292, 300, 236, 526, 140, 167, 306, 135, 143, 279, 99, 320, 407, 226, 445]

# %%
# Plot Differences in Opportunities
Axis([
    Plots.Linear(1:24, sdev_diff[1, :], legendentry="Start of Window")
    Plots.Linear(1:24, sdev_diff[2, :], legendentry="End of Window")
    Plots.Linear(1:24, sdev_diff[3, :], legendentry="Window Duration")
    Plots.Linear(1:24, missing_opportunities, legendentry="Number of Missing Opportunities")
], width="10cm", height="10cm", legendPos="north west", xmin=0, xmax=24, ymin=0)
# Out:
# Axis(PGFPlots.Plots.Plot[Linear(Real[1.0 2.0 … 23.0 24.0; 13.5461 21.4995 … 136.47 145.236], nothing, nothing, nothing, "Start of Window", nothing, nothing), Linear(Real[1.0 2.0 … 23.0 24.0; 14.9862 23.488 … 141.803 148.496], nothing, nothing, nothing, "End of Window", nothing, nothing), Linear(Real[1.0 2.0 … 23.0 24.0; 10.1799 7.22966 … 22.906 23.4955], nothing, nothing, nothing, "Window Duration", nothing, nothing), Linear(Real[1 2 … 23 24; 95 354 … 226 445], nothing, nothing, nothing, "Number of Missing Opportunities", nothing, nothing)], nothing, nothing, nothing, nothing, nothing, nothing, nothing, 0, 24, 0, nothing, nothing, nothing, nothing, nothing, nothing, "10cm", "10cm", nothing, "north west", nothing, nothing, nothing, nothing, nothing, nothing, "axis")

# %%
# Graph planning
@time path, reward, image_list = sp_graph_policy(collects, Function[constraint_agility_single_axis], horizon=0.0, allow_repeats=false)
graph_path, graph_reward, graph_image_list = path, reward, image_list

println("Total planning reward: $reward")
println("Number of images collected: $(length(image_list))/$num_images, $(length(image_list)/num_images*100)")
println("Number of feasible images collected: $(length(image_list))/$num_feasible, $(length(image_list)/num_feasible*100)")

graph_feasible = sp_check_feasibility(graph_path, Function[constraint_agility_single_axis])
println("GRAPH Constraint Check: $(graph_feasible ? "PASS" : "FAIL")")
# Out:
# 32216.937405 seconds (4.17 G allocations: 226.371 GiB, 96.97% gc time)
# Total planning reward: 1007.0
# Number of images collected: 1007/1200, 83.91666666666666
# Number of feasible images collected: 1007/1062, 94.8210922787194
# GRAPH Constraint Check: PASS

# %%
# MILP planning
@time path, reward, image_list = sp_milp_policy(collects, Function[constraint_agility_single_axis], horizon=0.0, allow_repeats=false)
milp_path, milp_reward, milp_image_list = path, reward, image_list

println("Total planning reward: $reward")
println("Number of images collected: $(length(image_list))/$num_images, $(length(image_list)/num_images*100)")
println("Number of feasible images collected: $(length(image_list))/$num_feasible, $(length(image_list)/num_feasible*100)")

milp_feasible = sp_check_feasibility(milp_path, Function[constraint_agility_single_axis])
println("MILP Constraint Check: $(milp_feasible ? "PASS" : "FAIL")")

# %%
# MDP Planning

# Pre-compute collect probability
@time col_prob = compute_collect_probability(collects, perturbed_opportunities[1:10]);
# Out:
# 106.077555 seconds (1.02 M allocations: 47.199 MiB, 0.01% gc time)

# %%
# Test MDP Forward Search Solution
@time path, reward, image_list = mdp_forward_search(collects, Function[constraint_agility_single_axis], 
                                                    images, col_prob,
                                                    horizon=4000, gamma=0.7, search_depth=1);

mdp_path, mdp_reward, mdp_image_list = path, reward, image_list

println("Total planning reward: $reward")
println("Number of images collected: $(length(image_list))/$num_images, $(length(image_list)/num_images*100)")
println("Number of feasible images collected: $(length(image_list))/$num_feasible, $(length(image_list)/num_feasible*100)")

mdp_feasible = sp_check_feasibility(path, Function[constraint_agility_single_axis])
println("MDP Constraint Check: $(mdp_feasible ? "PASS" : "FAIL")")
# Out:
# Number of all images: 1200, Collected: 801, Missed: 399
# 385.821424 seconds (2.87 G allocations: 105.118 GiB, 12.00% gc time)
# Total planning reward: 801.0
# Number of images collected: 801/1200, 66.75
# Number of feasible images collected: 801/1062, 75.42372881355932
# MDP Constraint Check: PASS

# %%
realized_rewards, mean_reward, sdev_reward = sp_compute_collect(graph_path, perturbed_opportunities[11:end])
# Out:
# ([949.0, 919.0, 130.0, 724.0, 319.0, 758.0, 128.0, 958.0, 778.0, 234.0  …  139.0, 918.0, 884.0, 987.0, 991.0, 349.0, 170.0, 757.0, 480.0, 197.0], 554.94, 352.00378269317366)

# %%
realized_rewards, mean_reward, sdev_reward = sp_compute_collect(milp_path, perturbed_opportunities[11:end])
# Out:
# UndefVarError: milp_path not defined
#
# Stacktrace:
#  [1] top-level scope at In[16]:1

# %%
realized_rewards, mean_reward, sdev_reward = sp_compute_collect(mdp_path, perturbed_opportunities[11:end])
# Out:
# ([775.0, 759.0, 144.0, 595.0, 411.0, 631.0, 148.0, 779.0, 644.0, 295.0  …  160.0, 766.0, 729.0, 800.0, 793.0, 425.0, 194.0, 626.0, 544.0, 245.0], 494.21, 259.6048782829067)
